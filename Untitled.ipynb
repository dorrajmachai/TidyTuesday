# %%
packages <- c("patchwork", "tidyverse", "tidytuesdayR", "ggthemes")
lapply(packages, library, character.only = TRUE)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# [[1]]
# [1] "patchwork" "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
#  [1] "forcats"   "stringr"   "dplyr"     "purrr"     "readr"     "tidyr"
#  [7] "tibble"    "ggplot2"   "tidyverse" "patchwork" "stats"     "graphics"
# [13] "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[3]]
#  [1] "tidytuesdayR" "forcats"      "stringr"      "dplyr"        "purrr"
#  [6] "readr"        "tidyr"        "tibble"       "ggplot2"      "tidyverse"
# [11] "patchwork"    "stats"        "graphics"     "grDevices"    "utils"
# [16] "datasets"     "methods"      "base"
#
# [[4]]
#  [1] "ggthemes"     "tidytuesdayR" "forcats"      "stringr"      "dplyr"
#  [6] "purrr"        "readr"        "tidyr"        "tibble"       "ggplot2"
# [11] "tidyverse"    "patchwork"    "stats"        "graphics"     "grDevices"
# [16] "utils"        "datasets"     "methods"      "base"

# %%
tuesdata <- tidytuesdayR::tt_load(2022, week = 51)
# Out:
# --- Compiling #TidyTuesday Information for 2022-12-20 ----
#
# --- There are 3 files available ---
#
# --- Starting Download ---
# 	Downloading file 1 of 3: `weather_forecasts.csv`
# 	Downloading file 2 of 3: `cities.csv`
# 	Downloading file 3 of 3: `outlook_meanings.csv`
# --- Download complete ---

# %%
forecasts <- tuesdata$weather_forecasts
cities <- tuesdata$cities
outlook <- tuesdata$outlook_meanings

head(forecasts)
head(cities)
head(outlook)
# Out:
#   date       city    state high_or_low forecast_hours_before observed_temp
# 1 2021-01-30 ABILENE TX    high        48                    70
# 2 2021-01-30 ABILENE TX    high        36                    70
# 3 2021-01-30 ABILENE TX    high        24                    70
# 4 2021-01-30 ABILENE TX    high        12                    70
# 5 2021-01-30 ABILENE TX    low         48                    42
# 6 2021-01-30 ABILENE TX    low         36                    42
#   forecast_temp observed_precip forecast_outlook possible_error
# 1 NA            0               NA               none
# 2 NA            0               NA               none
# 3 NA            0               NA               none
# 4 70            0               DUST             none
# 5 NA            0               NA               none
# 6 NA            0               NA               none
#   city         state lon     lat   koppen elevation distance_to_coast wind
# 1 ABILENE      TX     -99.68 32.41 Cfa     545.46   328.89            4.43
# 2 AKRON_CANTON OH     -81.44 40.92 Dfa     370.43   329.70            4.28
# 3 ALBANY       NY     -73.80 42.75 Dfb      84.99    99.80            3.28
# 4 ALBUQUERQUE  NM    -106.61 35.04 BSk    1619.93   518.82            3.04
# 5 ALLENTOWN    PA     -75.49 40.57 Dfa     117.73    48.40            3.34
# 6 AMARILLO     TX    -101.72 35.22 BSk    1098.16   568.23            5.14
#   elevation_change_four elevation_change_eight avg_annual_precip
# 1  66.72                 66.72                 26.760
# 2  64.66                 64.66                 44.686
# 3  79.31                 97.42                 44.660
# 4 112.19                146.77                 10.143
# 5  44.82                143.50                 52.318
# 6  31.50                 72.41                 20.165
#   forecast_outlook meaning
# 1 DUST             Dust
# 2 SUNNY            Sunny
# 3 MOCLDY           Mostly Cloudy
# 4 SNOW             Snow
# 5 PTCLDY           Partly Cloudy
# 6 RAIN             Rain

# %%
colorado <- forecasts %>%
    filter(state == "CO") %>%
    drop_na(forecast_temp)

head(colorado)
# Out:
#   date       city          state high_or_low forecast_hours_before
# 1 2021-01-30 COLORADO_SPGS CO    high        12
# 2 2021-01-30 COLORADO_SPGS CO    low         24
# 3 2021-01-30 COLORADO_SPGS CO    low         12
# 4 2021-01-30 PUEBLO        CO    high        12
# 5 2021-01-30 PUEBLO        CO    low         24
# 6 2021-01-30 PUEBLO        CO    low         12
#   observed_temp forecast_temp observed_precip forecast_outlook possible_error
# 1 51            49            0               WINDY            none
# 2 25            17            0               WINDY            none
# 3 25            18            0               SUNNY            none
# 4 58            55            0               WINDY            none
# 5 24            17            0               WINDY            none
# 6 24            18            0               SUNNY            none

# %%
options(repr.plot.width = 15, repr.plot.height = 10)

colorado %>%
    ggplot(aes(x = forecast_outlook)) +
    geom_bar(aes(fill = city), position = position_dodge(width = 0.7)) +
    theme(axis.text.x = element_text(angle = 90, vjust = 1))
# Out:
# plot without title

# %%
co_cities <- cities %>%
    filter(state == "CO")

head(co_cities)
# Out:
#   city           state lon       lat      koppen elevation distance_to_coast
# 1 COLORADO_SPGS  CO    -104.6900 38.81000 BSk    1880.21   781.99
# 2 DENVER         CO    -104.7600 39.71000 BSk    1702.26   821.65
# 3 GRAND_JUNCTION CO    -108.5386 39.13389 BSk    1468.39   630.87
# 4 PUEBLO         CO    -104.5100 38.29000 BSk    1425.33   767.71
#   wind elevation_change_four elevation_change_eight avg_annual_precip
# 1 3.34 142.48                341.44                 17.575
# 2 3.24 121.03                131.04                 17.453
# 3 2.30 498.36                498.36                 11.306
# 4 3.07 116.10                131.75                 14.045

# %%
head(colorado)
head(co_cities)
# Out:
#   date       city          state high_or_low forecast_hours_before
# 1 2021-01-30 COLORADO_SPGS CO    high        12
# 2 2021-01-30 COLORADO_SPGS CO    low         24
# 3 2021-01-30 COLORADO_SPGS CO    low         12
# 4 2021-01-30 PUEBLO        CO    high        12
# 5 2021-01-30 PUEBLO        CO    low         24
# 6 2021-01-30 PUEBLO        CO    low         12
#   observed_temp forecast_temp observed_precip forecast_outlook possible_error
# 1 51            49            0               WINDY            none
# 2 25            17            0               WINDY            none
# 3 25            18            0               SUNNY            none
# 4 58            55            0               WINDY            none
# 5 24            17            0               WINDY            none
# 6 24            18            0               SUNNY            none
#   city           state lon       lat      koppen elevation distance_to_coast
# 1 COLORADO_SPGS  CO    -104.6900 38.81000 BSk    1880.21   781.99
# 2 DENVER         CO    -104.7600 39.71000 BSk    1702.26   821.65
# 3 GRAND_JUNCTION CO    -108.5386 39.13389 BSk    1468.39   630.87
# 4 PUEBLO         CO    -104.5100 38.29000 BSk    1425.33   767.71
#   wind elevation_change_four elevation_change_eight avg_annual_precip
# 1 3.34 142.48                341.44                 17.575
# 2 3.24 121.03                131.04                 17.453
# 3 2.30 498.36                498.36                 11.306
# 4 3.07 116.10                131.75                 14.045

# %%
options(repr.plot.width = 25, repr.plot.height = 10)

q1 <- colorado %>%
    filter(city == "COLORADO_SPGS") %>%
    ggplot(aes(x = date)) +
    geom_point(aes(y = forecast_temp), 
              color = "blue",
              size = 3,
              alpha = 1/10) +
    geom_point(aes(y = observed_temp), 
              color = "red",
              size = 3,
              alpha = 1/10) +
    scale_x_date(date_labels = "%W",
                 limits = as.Date(c("2021-01-30", "2021-3-30")))

q2 <- colorado %>%
    filter(city == "COLORADO_SPGS") %>%
    ggplot(aes(x = date)) +
    geom_point(aes(y = forecast_temp), 
              color = "blue",
              size = 3,
              alpha = 1/10) +
    geom_point(aes(y = observed_temp), 
              color = "red",
              size = 3,
              alpha = 1/10) +
    scale_x_date(date_labels = "%W",
                 limits = as.Date(c("2021-04-30", "2021-6-30")))

q3 <- colorado %>%
    filter(city == "COLORADO_SPGS") %>%
    ggplot(aes(x = date)) +
    geom_point(aes(y = forecast_temp), 
              color = "blue",
              size = 3,
              alpha = 1/10) +
    geom_point(aes(y = observed_temp), 
              color = "red",
              size = 3,
              alpha = 1/10) +
    scale_x_date(date_labels = "%W",
                 limits = as.Date(c("2021-07-30", "2021-9-30")))

q4 <- colorado %>%
    filter(city == "COLORADO_SPGS") %>%
    ggplot(aes(x = date)) +
    geom_point(aes(y = forecast_temp), 
              color = "blue",
              size = 3,
              alpha = 1/10) +
    geom_point(aes(y = observed_temp), 
              color = "red",
              size = 3,
              alpha = 1/10) +
    scale_x_date(date_labels = "%W",
                 limits = as.Date(c("2021-10-30", "2021-12-30")))

q1 + q2 + q3 + q4 + plot_layout(ncol = 4)
# Out:
# Warning message:
# “Removed 3217 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3217 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3195 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3195 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3193 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3247 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3199 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 3199 rows containing missing values (`geom_point()`).”
# plot without title

# %%
colorado %>%
   filter()
# Out:
# Error in parse(text = x, srcfile = src): <text>:3:0: unexpected end of input
# 1: colorado %>%
# 2:
#   ^
# Traceback:
